# %% [markdown]
# # Cargue inicial

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, OrdinalEncoder
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler,MaxAbsScaler,Normalizer

# %%
df = pd.read_csv('https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv')

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # EDA

# %%
# Realizado en el notebook de EDA

# %% [markdown]
# # Revisión de duplicados

# %%
duplicados = df.duplicated().sum()
print(df.duplicated().sum())
# Out:
# 0

# %%
duplicados = df.duplicated(subset=['PassengerId']).sum()
print(df.duplicated(subset=['PassengerId']).sum())
# Out:
# 0

# %%
duplicados = df[df.duplicated()]
duplicados
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
# df.drop_duplicates()

# %% [markdown]
# # Revisión de nulos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
nulos = df.isnull().sum()
nulos
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#df2 = df   cualquier cambio afecta al dataframe(df) original
#df2 = df.copy()   este crea una copia aislada

# %%
pct_nulos = df.isnull().mean()*100
pct_nulos
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %% [markdown]
# Si % de nulos <5% : Eliminar
#
# Si % 5% y el 30% : Imputación de datos
#
# Si es 30%: Analizar a detalle que tanto aporta

# %%
df_age_analysis_mean = df.copy()
df_age_analysis_median = df.copy()

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 881          882         0       3                       Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss Gerda Ulrika
# 883          884         0       2            Banfield, Mr. Frederick James
# 884          885         0       3                   Sutehall, Mr. Henry Jr
# 885          886         0       3     Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                    Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss Margaret Edith
# 888          889         0       3  Johnston, Miss Catherine Helen "Carrie"
# 889          890         1       1                    Behr, Mr. Karl Howell
# 890          891         0       3                      Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df_age_analysis_mean['Age'] = df_age_analysis_mean['Age'].fillna(df_age_analysis_mean['Age'].mean())

# %%
df_age_analysis_mean.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex        Age  \
# 0                            Braund, Mr. Owen Harris    male  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                              Heikkinen, Miss Laina  female  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                           Allen, Mr. William Henry    male  35.000000
# 5                                   Moran, Mr. James    male  29.699118
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      1      0         A/5 21171   7.2500   NaN        S
# 1      1      0          PC 17599  71.2833   C85        C
# ...

# %%
df_age_analysis_median['Age'] = df_age_analysis_median['Age'].fillna(df_age_analysis_median['Age'].median())

# %%
df_age_analysis_median.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male  28.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
df_median_agrup = df.copy()
df_median_agrup['Age'] = df_median_agrup['Age'].fillna(df_median_agrup.groupby(['Pclass','Sex'])['Age'].transform('median'))
df_median_agrup.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male  25.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
df_knn = df.copy()
features_columns = ['Age', 'Pclass']
imputer = KNNImputer(n_neighbors=6)
df_knn[features_columns] = imputer.fit_transform(df_knn[features_columns])
df_knn.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0     3.0
# 1            2         1     1.0
# 2            3         1     3.0
# 3            4         1     1.0
# 4            5         0     3.0
# 5            6         0     3.0
#
#                                                 Name     Sex        Age  \
# 0                            Braund, Mr. Owen Harris    male  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                              Heikkinen, Miss Laina  female  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                           Allen, Mr. William Henry    male  35.000000
# 5                                   Moran, Mr. James    male  21.833333
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      1      0         A/5 21171   7.2500   NaN        S
# 1      1      0          PC 17599  71.2833   C85        C
# ...

# %%
df_mode = df.copy()
df_mode['Embarked'] = df_mode['Embarked'].fillna(df_mode['Embarked'].mode()[0])
df_mode.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# # Tratamiento de outliers

# %%
# Análisis de Edad

# %%
Q1 = df['Age'].quantile(0.25)
Q3 = df['Age'].quantile(0.75)
IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

outliers = df[(df['Age'] < limite_inferior) | (df['Age'] > limite_superior)]
outliers
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 280          281         0       3                      Duane, Mr. Frank
# 456          457         0       1             Millet, Mr. Francis Davis
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# ...

# %%
sns.set_style('whitegrid')
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
Q1 = df['Fare'].quantile(0.25)
Q3 = df['Fare'].quantile(0.75)
IQR = Q3 - Q1

limite_inferior = Q1 - 3 * IQR
limite_superior = Q3 + 3 * IQR

outliers = df[(df['Fare'] < limite_inferior) | (df['Fare'] > limite_superior)]
outliers

# %%
# Z - score
df_zcore = df.copy()
media = df['Age'].mean()
desviacion_estandar = df['Age'].std()

df_zcore['z_score'] = (df_zcore['Age'] - media) / desviacion_estandar
df_zcore.head(10)

outliers = df_zcore[df_zcore['z_score'] > 3]
outliers
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch  Ticket    Fare Cabin Embarked   z_score
# 630  male  80.0      0      0   27042  30.000   A23        S  3.462699
# 851  male  74.0      0      0  347060   7.775   NaN        S  3.049660

# %%
sns.boxplot(x=df['Fare'])
# Out:
# <Axes: xlabel='Fare'>

# %% [markdown]
# #  Encode de variables categoricas

# %%
df_encode = df.copy()
df_encode['Pclass'] = df_encode['Pclass'].astype(str)

encode = OrdinalEncoder(categories=[["3","2","1"]])
df_encode['Pclass_new'] = encode.fit_transform(df_encode[['Pclass']])
df_encode.head(10)
# Out:
#    PassengerId  Survived Pclass  \
# 0            1         0      3
# 1            2         1      1
# 2            3         1      3
# 3            4         1      1
# 4            5         0      3
# 5            6         0      3
# 6            7         0      1
# 7            8         0      3
# 8            9         1      3
# 9           10         1      2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %%
df_dummies = df.copy()
df_dummies = pd.get_dummies(df_dummies, columns=['Sex'], drop_first=True)
df_dummies.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                              Heikkinen, Miss Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
# 5                                   Moran, Mr. James   NaN      0      0
# 6                            McCarthy, Mr. Timothy J  54.0      0      0
# ...

# %%
df_label = df.copy()
label = LabelEncoder()
df_label['Sex_new'] = label.fit_transform(df_label['Sex'])
df_label.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df_label = df.copy()
label = LabelEncoder()
df_label['Embarked_new'] = label.fit_transform(df_label['Embarked'])
df_label.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# # Transformaciones, normalizacion de datos

# %%
scaler = MinMaxScaler()
df_scaler = df.copy()
df_scaler[['Age', 'Fare']] = scaler.fit_transform(df_scaler[['Age', 'Fare']])
df_scaler.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex       Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  0.271174      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  0.472229      1
# 2                              Heikkinen, Miss Laina  female  0.321438      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  0.434531      1
# 4                           Allen, Mr. William Henry    male  0.434531      0
# 5                                   Moran, Mr. James    male       NaN      0
# ...

# %%
scaler = StandardScaler()
df_scaler = df.copy()
df_scaler[['Age', 'Fare']] = scaler.fit_transform(df_scaler[['Age', 'Fare']])
df_scaler.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex       Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male -0.530377      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  0.571831      1
# 2                              Heikkinen, Miss Laina  female -0.254825      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  0.365167      1
# 4                           Allen, Mr. William Henry    male  0.365167      0
# 5                                   Moran, Mr. James    male       NaN      0
# ...

# %%
scaler = MaxAbsScaler()
df_scaler = df.copy()
df_scaler[['Age', 'Fare']] = scaler.fit_transform(df_scaler[['Age', 'Fare']])
df_scaler.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex     Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  0.2750      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  0.4750      1
# 2                              Heikkinen, Miss Laina  female  0.3250      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  0.4375      1
# 4                           Allen, Mr. William Henry    male  0.4375      0
# 5                                   Moran, Mr. James    male     NaN      0
# ...
